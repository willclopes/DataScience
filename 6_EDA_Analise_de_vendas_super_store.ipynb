# %% [markdown]
# <a href="https://colab.research.google.com/github/willclopes/Portfolio-Data-Science/blob/master/6_EDA_Analise_de_vendas_super_store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de vendas em uma Super Store
#
#
# ---
# By Willian C Lopes

# %% [markdown]
# ![60f0d1f927c82.png](data:image/png;base64,...)

# %% [markdown]
# ## Contexto: O que é análise de vendas?
#
# Análise de vendas é a prática de gerar insights de dados de vendas, tendências e métricas para definir metas e prever o desempenho de vendas futuro. A prática recomendada para análise de vendas é vincular estreitamente todas as atividades para determinar os resultados da receita e definir objetivos para sua equipe de vendas.
#
# A análise deve se concentrar na melhoria e no desenvolvimento de uma estratégia para melhorar o desempenho de vendas a curto e longo prazo. Um exemplo comum de atividade de análise de vendas é definir objetivos específicos de função para sua equipe na forma de KPIs (*Key Performance Indicator*) ou métricas. Por exemplo, definir uma meta de receita para seu diretor de vendas e, ao mesmo tempo, definir uma meta de produtividade de vendas para sua equipe de gerenciamento de contas.

# %% [markdown]
# ## Por que monitorar a análise de vendas?
#
# Se o seu negócio fosse uma banda de rock, as vendas seriam o vocalista. Todos os olhos estão voltados para o desempenho de vendas e receita, e um desempenho forte (ou fraco) pode se tornar uma força de mobilização potente para toda a equipe.
#
# O monitoramento da análise de vendas na forma de métricas de vendas ajuda a aumentar seu desempenho, otimizar as atividades de vendas e melhorar a responsabilidade. Sua equipe de vendas tem uma ampla gama de atividades para se concentrar e operar em um ambiente de ritmo acelerado. Uma estratégia de análise de vendas bem definida fornece à sua equipe foco e clareza para que eles possam se concentrar em fazer o que fazem melhor.
#
#
# ## O que é a EDA
#
# A EDA ou análise exploratória de dados é uma etapa importante do aprendizado de máquina que envolve aprender sobre os dados sem gastar muito tempo ou se perder nisso. Nesse processo você se familiariza com a estrutura e as características gerais do conjunto de dados, com os recursos independentes e dependentes e suas interações. Você também terá uma ideia dos processos de limpeza de dados a serem empregados e das possíveis técnicas de modelagem.
#
# ## Descrição dos dados e declaração do problema:
#
# Este é um exemplo de conjunto de dados de uma super loja. Com essa amostra pode-se realizar sumulações em que você executa uma análise extensa de dados para fornecer insights sobre como a empresa pode aumentar seus lucros, minimizando as perdas.
#
# Os atributos são:
#
# * 'Modo de envio' é o método de envio de mercadorias físicas e produtos aos clientes pretendidos
# * 'Segmento' especifica o segmento de clientes ou grupos de marketing de acordo com seus interesses e dados demográficos
# * 'País' está todo nos Estados Unidos da América (EUA),
# * 'Cidade' refere-se às cidades nos EUA
# * 'Estado' é composto pelos estados dos EUA,
# * 'Código Postal' denota o endereço de destino postal classificado pelas regiões nos EUA
# * 'Região' região do país
# 'Categoria' consiste nos grupos nomeados de produtos físicos semelhantes e definidos
# * 'Subcategoria' lista as subdivisões em relação a uma determinada categoria
# * 'Vendas' são o valor monetário das transações entre a Superloja e seus clientes de produtos físicos em medidas em dólares americanos (USD $)
# * 'Quantidade' registra o número de tais produtos em cada transação de venda
# * 'Desconto' indica a porcentagem de dedução monetária do preço normal do produto
# * 'Lucro' são os ganhos financeiros em dólares americanos de cada transação.
#
#
# Iremos pré-processar e explorar os dados, em seguida, encontrar algumas respostas para as perguntas:
#
# 1. Qual categoria é a mais vendida e mais lucrativa?
# 2. Quais são as subcategorias mais vendidas e mais lucrativas?
# 3. Qual é a subcategoria mais vendida?
# 4. Qual segmento de cliente é mais lucrativo?
# 5. Qual é o modo de envio preferido?
# 6. Qual região é a mais lucrativa?
# 7. Qual cidade tem o maior número de vendas?
#
# O objetivo deste processo é dar mais informações sobre os nossos dados para que a equipe de marketing se prepare para intensificar a eficiência a partir dos dados e informações que iremos disponibilizar!
#
#
# Você pode acompanhar baixando o conjunto de dados pelo [meu github](https://raw.githubusercontent.com/willclopes/Portfolio-Datasets/main/sample_superstore.csv) ou pelo [Kaggle](https://www.kaggle.com/bravehart101/sample-supermarket-dataset).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Importar as Bibliotecas e o DataSet
#
# A primeira etapa é importar as bibliotecas que usaremos em todo o projeto EDA. Em seguida, lemos o **train.csv** que baixei e salvei no meu github. Vamos a EDA no conjunto de **treino** porque ele contém a variável de destino e estamos interessados ​​em compreender os recursos individuais, bem como sua relação com o atributo de destino.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

import warnings
warnings.filterwarnings("ignore")

# %%
 superstore = pd.read_csv("https://raw.githubusercontent.com/willclopes/Portfolio-Datasets/main/sample_superstore.csv")

# %%
superstore.shape
# Out:
# (9994, 13)

# %%
superstore.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ## Exploração de conjunto de dados básicos
#
# ### 1. Forma (dimensões) do DataFrame
#
# Um DataFrame tem linhas e colunas, e o atributo **.shape** do Pandas retorna uma tupla de comprimento 2, cada valor mostrando o comprimento de cada dimensão ou (linhas, colunas).
#
# Podemos ver que o conjunto de dados possui 9.994 linhas e 13 colunas.
#
# ### 2. Tipos de dados das várias colunas
#
# Logo após, exibiremos todos os tipos de dados das colunas. Isso nos ajuda a entender o tipo de dados com os quais estamos lidando, em termos de distribuições numéricas e categóricas. Isso também lançará luz sobre alguns dos gráficos e plotagens exploratórias a serem usados.

# %% [markdown]
# Vamos dar uma olha nas 5 primeiras e 5 últimas linhas do nosso dataset

# %%
superstore.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
superstore.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %% [markdown]
# Podemos afirmar facilmente que existe uma **mistura de variáveis** ​​categóricas, geográficas e numéricas.
#
# Cada linha representa um pedido de um item e a quantidade, vendas, desconto e lucro correspondentes. Há também o modo de envio, segmento do cliente e aspectos geográficos.

# %% [markdown]
# ## Limpeza de Dados
#
# Antes de começarmos com a análise, devemos primeiro limpar os dados ou “limpar a sujeira”. Para esta análise, examinaremos os problemas mais comuns, como dados ausentes e duplicados.
#
# ### Tratamento de valores ausentes
#
# Aqui, descobriremos se existe um valor Nulo.

# %%
superstore.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# O resultado mostra que o conjunto de dados não possui nenhum valor nulo.
#
# ### Dados duplicados
#
# Em seguida, descobriremos se há dados duplicados.

# %%
superstore.duplicated().sum()
# Out:
# 17

# %% [markdown]
# O resultado mostra que existem 17 linhas duplicadas. Vamos executar outra função para visualizar os dados duplicados.

# %%
superstore[superstore.duplicated(keep = 'last')]
# Out:
#            Ship Mode      Segment        Country  ... Quantity Discount   Profit
# 568   Standard Class    Corporate  United States  ...        3      0.0   9.3312
# 591   Standard Class     Consumer  United States  ...        2      0.2   3.6288
# 935   Standard Class  Home Office  United States  ...        3      0.2   5.4432
# 1186  Standard Class    Corporate  United States  ...        4      0.0  12.4416
# 1479  Standard Class     Consumer  United States  ...        4      0.0  12.4416
# 2803  Standard Class     Consumer  United States  ...        3      0.0   5.7780
# 2807    Second Class     Consumer  United States  ...        2      0.0   6.2208
# 2836  Standard Class     Consumer  United States  ...        3      0.0   9.3312
# 3127  Standard Class     Consumer  United States  ...        4      0.0  23.0864
# 3405  Standard Class  Home Office  United States  ...        2      0.3 -12.0588
# 3412  Standard Class    Corporate  United States  ...        4      0.0   3.1752
# ...

# %% [markdown]
# Em seguida, executaremos a função drop_duplicates () para eliminar as linhas duplicadas.

# %%
superstore.drop_duplicates(inplace = True)
superstore.shape
# Out:
# (9977, 13)

# %% [markdown]
# Agora sim! Podemos confirmar que as linhas duplicadas foram eliminadas porque as linhas eram 9993 antes e agora estão reduzidas para 9977 linhas.

# %% [markdown]
# ## Feature Engineering
#
# Feature engineering é o termo utilizado para definir um conjunto de técnicas utilizado na criação e manipulação de features (recursos), tendo como objetivo desenvolver um bom modelo de aprendizado de máquina. Esse processo também abrange a **transformação matemática nas features existentes** para **extrair o máximo potencial dos dados e criação de novas features.**
#
# Vamos criar uma nova coluna calculando a margem de lucro. A fórmula é (Lucro / Vendas) * 100.

# %%
superstore['Profit Margin %'] = (superstore.Profit / superstore.Sales) * 100
superstore.head(5)
# Out:
#         Ship Mode    Segment  ...    Profit Profit Margin %
# 0    Second Class   Consumer  ...   41.9136           16.00
# 1    Second Class   Consumer  ...  219.5820           30.00
# 2    Second Class  Corporate  ...    6.8714           47.00
# 3  Standard Class   Consumer  ... -383.0310          -40.00
# 4  Standard Class   Consumer  ...    2.5164           11.25
#
# [5 rows x 14 columns]

# %% [markdown]
# Agora que o conjunto de dados foi limpo, podemos prosseguir com algumas análises estatísticas!

# %% [markdown]
# ## Estatísticas descritivas
# Aqui, faremos uma análise estatística descritiva. Usamos df.describe () e atribuímos 'include =' all 'para garantir que os recursos categóricos também sejam incluídos na saída.

# %%
superstore.describe(include = "all")
# Out:
#              Ship Mode   Segment  ...      Profit Profit Margin %
# count             9977      9977  ...  9977.00000     9977.000000
# unique               4         3  ...         NaN             NaN
# top     Standard Class  Consumer  ...         NaN             NaN
# freq              5955      5183  ...         NaN             NaN
# mean               NaN       NaN  ...    28.69013       12.011354
# std                NaN       NaN  ...   234.45784       46.663769
# min                NaN       NaN  ... -6599.97800     -275.000000
# 25%                NaN       NaN  ...     1.72620        7.500000
# 50%                NaN       NaN  ...     8.67100       27.000000
# 75%                NaN       NaN  ...    29.37200       36.250000
# max                NaN       NaN  ...  8399.97600       50.000000
#
# [11 rows x 14 columns]

# %% [markdown]
# Pode-se ver 'NaN' em algumas das colunas categóricas e isso é perfeitamente normal. Os valores categóricos não devem ter cálculos realizados sobre eles, portanto, podemos ignorá-los.
#
# O que queremos enfocar é a contagem e frequência únicas dos recursos categóricos, como:
#
# * Existem 4 modos de envio e 3 segmentos de cliente. Quase metade dos pedidos são do segmento de consumidor usando remessa de classe padrão.
#
# * A loja possui 3 categorias de itens com 17 subcategorias. 60% dos pedidos são para material de escritório e pelo menos 15% das compras são para fichários.
#
# Enquanto para parâmetros numéricos, é interessante notar que:
#
# * 75% dos pedidos geram pelo menos 36% de margem de lucro.
#
# * Pedidos com prejuízo podem chegar a 275% de perdas. Devemos enfatizar essas vendas deficitárias para eliminá-las.
#
# Faremos algumas análises abaixo para testar essas observações.

# %% [markdown]
# ## Análise exploratória de dados
#
# ### 1. Qual categoria é a mais vendida e mais lucrativa?
#
# (Mais vendido significa olhar para as vendas e ver qual categoria está sendo mais lucrativa em vendas. Vamos agrupar Vendas, Lucro e também Quantidade por Categoria e executar as funções df.group (). Sum e pd.DataFrame ().)

# %%
# Primeiro vamos agrupar por categoria
category_analysis = pd.DataFrame(superstore.groupby(['Category'])[['Sales', 'Profit', 'Quantity']].sum())
category_analysis
# Out:
#                        Sales       Profit  Quantity
# Category
# Furniture        741306.3133   18421.8137      8020
# Office Supplies  718735.2440  122364.6608     22861
# Technology       836154.0330  145454.9481      6939

# %%
# difinir o formato do gráfico
sns.set_theme(style="whitegrid")
figure, axis = plt.subplots(1, 3, figsize=(8, 5))
# critar os plots
cat1 = sns.barplot(x = category_analysis.index, y = category_analysis.Sales, ax=axis[0])
cat2 = sns.barplot(x = category_analysis.index, y = category_analysis.Profit, ax=axis[1])
cat3 = sns.barplot(x = category_analysis.index, y = category_analysis.Quantity, ax=axis[2])
# definir os titulos
cat1.set(title = 'Vendas')
cat2.set(title = 'Lucro')
cat3.set(title = 'Quantidade')
# rotacionar os eixos
plt.setp(cat1.get_xticklabels(), rotation = 'vertical', size = 9)
plt.setp(cat2.get_xticklabels(), rotation = 'vertical', size = 9)
plt.setp(cat3.get_xticklabels(), rotation = 'vertical', size = 9)
# definir o espaçamento
figure.tight_layout()

# %% [markdown]
# As observações são:
#
# * Todas as 3 categorias - Móveis, Material de Escritório e Tecnologia têm vendas semelhantes.
#
# * Tecnologia é a mais vendida e é bom saber que essa categoria também é a mais lucrativa. Apenas uma quantidade mínima é vendida, pois esses produtos geralmente são compras únicas que podem durar pelo menos 4-5 anos.
#
# * Embora Móveis faça vendas semelhantes às de Tecnologia, é o menos lucrativo e a quantidade vendida também é mínima.
#
# * O material de escritório vende mais em termos de quantidade, pois é um produto relativamente barato.

# %% [markdown]
# ### 2. Quais são as subcategorias mais vendidas e mais lucrativas?

# %%
# agrupar por sub-categoria
subcat_analysis = pd.DataFrame(superstore.groupby(['Sub-Category'])[['Sales', 'Profit']].sum())
# ordernar de acordo com "Sales"
subcat_sales = pd.DataFrame(subcat_analysis.sort_values('Sales', ascending = False))
subcat_sales
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        330007.0540  44515.7306
# Chairs        327777.7610  26567.1278
# Storage       223843.6080  21278.8264
# Tables        206965.5320 -17725.4811
# Binders       203409.1690  30228.0003
# Machines      189238.6310   3384.7569
# Accessories   167380.3180  41936.6357
# Copiers       149528.0300  55617.8249
# Bookcases     114879.9963  -3472.5560
# Appliances    107532.1610  18138.0054
# Furnishings    91683.0240  13052.7230
# Paper          78224.1420  33944.2395
# Supplies       46673.5380  -1189.0995
# Art            27107.0320   6524.6118
# Envelopes      16476.4020   6964.1767
# Labels         12444.9120   5526.3820
# Fasteners       3024.2800    949.5182

# %%
# ordernar de acordo com "Profit"
subcat_profit = pd.DataFrame(subcat_analysis.sort_values('Profit', ascending = False))
subcat_profit
# Out:
#                     Sales      Profit
# Sub-Category
# Copiers       149528.0300  55617.8249
# Phones        330007.0540  44515.7306
# Accessories   167380.3180  41936.6357
# Paper          78224.1420  33944.2395
# Binders       203409.1690  30228.0003
# Chairs        327777.7610  26567.1278
# Storage       223843.6080  21278.8264
# Appliances    107532.1610  18138.0054
# Furnishings    91683.0240  13052.7230
# Envelopes      16476.4020   6964.1767
# Art            27107.0320   6524.6118
# Labels         12444.9120   5526.3820
# Machines      189238.6310   3384.7569
# Fasteners       3024.2800    949.5182
# Supplies       46673.5380  -1189.0995
# Bookcases     114879.9963  -3472.5560
# Tables        206965.5320 -17725.4811

# %%
# Gerar os gráfico
sns.set_theme(style="whitegrid")

figure, axis = plt.subplots(1, 2, figsize=(12, 6))

subcat1 = sns.barplot(data = subcat_sales, x = subcat_sales.index, y = subcat_sales.Sales, ax=axis[0])
subcat1.set(title="Sub-Categoria mais vendida")
subcat1.set_xticklabels(subcat1.get_xticklabels(),rotation = "vertical", size = 10)

subcat2 = sns.barplot(data = subcat_profit, x = subcat_profit.index, y = subcat_profit.Profit, ax=axis[1])
subcat2.set(title = "Sub-Categoria mais lucrativa")
subcat2.set_xticklabels(subcat2.get_xticklabels(),rotation = "vertical", size = 10)

figure.tight_layout()
plt.show()

# %% [markdown]
# Vamos analisar os gráficos de barra:
#
# * Telefones e cadeiras são as 2 subcategorias mais vendidas.
#
# * As copiadoras geram mais lucro, seguidas por telefones, acessórios, papéis e pastas. A estratégia de marketing deve se concentrar no marketing desses produtos.
#
# * Na outra ponta do espectro, máquinas, fixadores, suprimentos, estantes e mesas têm uma margem de perdas próxima de zero. Esses são produtos que a
#
# * A Super Store pode considerar retirar do catálogo de produtos ou aumentar o preço de venda e a margem de lucro ou negociar por um preço mais baixo com o fornecedor.

# %% [markdown]
# ### 3. Qual é a subcategoria mais vendida?

# %%
subcat_quantity = pd.DataFrame(superstore.groupby(['Sub-Category'])[['Quantity']].sum().sort_values('Quantity',ascending=False))
subcat_quantity
# Out:
#               Quantity
# Sub-Category
# Binders           5971
# Paper             5144
# Furnishings       3560
# Phones            3289
# Storage           3158
# Art               2996
# Accessories       2976
# Chairs            2351
# Appliances        1729
# Labels            1396
# Tables            1241
# Fasteners          914
# Envelopes          906
# Bookcases          868
# Supplies           647
# Machines           440
# Copiers            234

# %%
# gráfico
sns.set_theme(style="whitegrid")
sns.barplot(data = subcat_quantity, y = subcat_quantity.index, x = subcat_quantity.Quantity, palette = "muted")
plt.title("Sub-Category mais lucrativa")
plt.show()

# %% [markdown]
# Aqui, podemos deduzir que
#
# * A super loja deve garantir que o estoque esteja sempre bem abastecido para a subcategoria mais vendida, como fichários, papel, móveis e telefones.
#
# * Apesar de ser mais rentável, as copiadoras vendem menos apenas 234, mas como se trata de um equipamento de escritório relativamente caro e costuma ser usado por poucos anos, é compreensível que vende menos entre todos.

# %% [markdown]
# ### 4. Qual segmento de cliente é mais lucrativo?

# %%
segment_analysis = pd.DataFrame(superstore.groupby(['Segment'])[['Profit']].sum())
segment_analysis
# Out:
#                   Profit
# Segment
# Consumer     134007.4413
# Corporate     91954.9798
# Home Office   60279.0015

# %%
# gráfico
sns.set_theme(style="whitegrid")
sns.barplot(data = segment_analysis, x = segment_analysis.index, y = segment_analysis.Profit, palette = "rocket")
plt.title("Segmento de clientes mais lucrativo")
plt.show()

# %% [markdown]
# O segmento de consumo é o mais lucrativo, seguido pelo Segmento Corporativo e Home Office. Conseqüentemente, a estratégia de marketing deve ter como alvo ou enfocar mais a retenção de clientes do segmento corporativo e de consumo.

# %% [markdown]
# ### 5. Qual é o modo de envio preferido?

# %%
sns.set_theme(style="whitegrid")
sns.countplot(superstore['Ship Mode'])
plt.title("Modo de Envio")
plt.show()

# %% [markdown]
# A "Classe Padrão" é o método de envio preferido e talvez o mais barato também. Os outros modos não são populares entre os clientes e podem ser muito caros.

# %% [markdown]
# ### 6. Qual região é a mais lucrativa?

# %%
region_analysis = pd.DataFrame(superstore.groupby(['Region'])['Profit'].sum().reset_index())
region_analysis
# Out:
#     Region       Profit
# 0  Central   39655.8752
# 1     East   91506.3092
# 2    South   46749.4303
# 3     West  108329.8079

# %%
# gráfico
explode = [0, 0, 0, 0.1]
plt.pie(region_analysis.Profit, labels = region_analysis.Region, startangle = 90, autopct = "%1.0f%%", explode = explode, shadow = True)
plt.title("Mais lucros por região")
plt.show()

# %% [markdown]
# As regiões Leste e Oeste são as mais lucrativas.

# %% [markdown]
# ### 7. Qual cidade tem o maior número de vendas?

# %%
city_sales = pd.DataFrame(superstore.groupby(['City'])['Sales', 'Quantity'].sum().sort_values('Sales',ascending = False))
top10 = city_sales[:10]
top10
# Out:
#                      Sales  Quantity
# City
# New York City  256319.0410      3413
# Los Angeles    175831.9010      2876
# Seattle        119460.2820      1578
# San Francisco  112577.1720      1920
# Philadelphia   109061.4610      1978
# Houston         64441.2564      1460
# Chicago         48535.9770      1129
# San Diego       47521.0290       670
# Jacksonville    44713.1830       429
# Springfield     43054.3420       649

# %%
bottom10 = city_sales[-10:]
bottom10
# Out:
#                  Sales  Quantity
# City
# Missouri City    6.370         7
# Keller           6.000         2
# Layton           4.960         4
# Springdale       4.300         2
# San Luis Obispo  3.620         2
# Ormond Beach     2.808         3
# Pensacola        2.214         3
# Jupiter          2.064         1
# Elyria           1.824         1
# Abilene          1.392         2

# %%
# gráfico
figure, axis = plt.subplots(1, 2, figsize=(12, 5))
sns.set_theme(style="whitegrid")
top10c = sns.barplot(data = top10, y = top10.index, x = top10.Sales, palette = "coolwarm", ax = axis[0])
top10c.set(Title = "As 10 cidades com vendas mais altas")
top10c.set_yticklabels(top10c.get_yticklabels(),size = 10)

bottom10c = sns.barplot(data = bottom10, y = bottom10.index, x = bottom10.Sales, palette = "coolwarm", ax=axis[1])
bottom10c.set(Title = "As 10 cidades com vendas mais baixas")
bottom10c.set_yticklabels(bottom10c.get_yticklabels(),size = 10)

figure.tight_layout()
plt.show()

# %% [markdown]
# Há uma grande disparidade entre as cidades com vendas mais altas e mais baixas. A estratégia de marketing deve ter como alvo as 10 principais cidades.

# %% [markdown]
# E é isso.

# %% [markdown]
# ## Referências
#
# * https://pandas.pydata.org/
# * https://seaborn.pydata.org/
# * https://medium.com/analytics-vidhya
# * https://www.kaggle.com/bravehart101/sample-supermarket-dataset
# * https://medium.com
# *

# %% [markdown]
# # Contatos
#
#
# [![github_original_wordmark_logo_icon_146506.png](data:image/png;base64,...)](https://github.com/willclopes)
#
#
# ---
#
#
# [![linkedin_black_logo_icon_147114.png](data:image/png;base64,...) ](https://www.linkedin.com/in/willclopes/)
#
#
#
#
#
# ---
#
# [![email.png](data:image/png;base64,...)](willclopes@gmail.com)
